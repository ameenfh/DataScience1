# %%
#Challenge 1
import pandas as pd
import seaborn as sns
from io import StringIO
import requests

# %%
url =  "https://api.imgflip.com/get_memes"
response = requests.get(url)
dictionary = response.json()
df = pd.DataFrame(dictionary["data"]["memes"])
df.head(10)
# Out:
#           id                                            name  \
# 0  181913649                             Drake Hotline Bling
# 1   87743020                                     Two Buttons
# 2  112126428                            Distracted Boyfriend
# 3  131087935                            Running Away Balloon
# 4  217743513                               UNO Draw 25 Cards
# 5  124822590                           Left Exit 12 Off Ramp
# 6  222403160  Bernie I Am Once Again Asking For Your Support
# 7  129242436                                  Change My Mind
# 8  247375501                            Buff Doge vs. Cheems
# 9    4087833                                Waiting Skeleton
#
#                                 url  width  height  box_count  captions
# 0  https://i.imgflip.com/30b1gx.jpg   1200    1200          2         0
# 1  https://i.imgflip.com/1g8my4.jpg    600     908          3         0
# 2  https://i.imgflip.com/1ur9b0.jpg   1200     800          3         0
# ...

# %%
url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjZmMxYjU4MWFhY2E2YzUyN2U3OTIzNmM4YzNiNmMzZCIsInN1YiI6IjY1MWQ4YTZiYzUwYWQyMDE0ZGQwMDhiNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Fo-lQULDUyxjBahYWlCQQoyVGEQceET6oEvh7Q7ZnvM"
}

pg1 = requests.get(url, headers=headers)



url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=2&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjZmMxYjU4MWFhY2E2YzUyN2U3OTIzNmM4YzNiNmMzZCIsInN1YiI6IjY1MWQ4YTZiYzUwYWQyMDE0ZGQwMDhiNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Fo-lQULDUyxjBahYWlCQQoyVGEQceET6oEvh7Q7ZnvM"
}

pg2 = requests.get(url, headers=headers)





url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=3&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjZmMxYjU4MWFhY2E2YzUyN2U3OTIzNmM4YzNiNmMzZCIsInN1YiI6IjY1MWQ4YTZiYzUwYWQyMDE0ZGQwMDhiNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Fo-lQULDUyxjBahYWlCQQoyVGEQceET6oEvh7Q7ZnvM"
}

pg3 = requests.get(url, headers=headers)




url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=4&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjZmMxYjU4MWFhY2E2YzUyN2U3OTIzNmM4YzNiNmMzZCIsInN1YiI6IjY1MWQ4YTZiYzUwYWQyMDE0ZGQwMDhiNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Fo-lQULDUyxjBahYWlCQQoyVGEQceET6oEvh7Q7ZnvM"
}

pg4 = requests.get(url, headers=headers)





url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=5&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjZmMxYjU4MWFhY2E2YzUyN2U3OTIzNmM4YzNiNmMzZCIsInN1YiI6IjY1MWQ4YTZiYzUwYWQyMDE0ZGQwMDhiNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.Fo-lQULDUyxjBahYWlCQQoyVGEQceET6oEvh7Q7ZnvM"
}

pg5 = requests.get(url, headers=headers)

# %%
pg1 = pg1.json()
pg2 = pg2.json()
pg3 = pg3.json()
pg4 = pg4.json()
pg5 = pg5.json()

# %%
langList = []



for i in range(len(pg1["results"])):
    language = pg1["results"][i]["original_language"]
    langList.append(language)

for i in range(len(pg2["results"])):
    language = pg2["results"][i]["original_language"]
    langList.append(language)
    

for i in range(len(pg3["results"])):
    language = pg3["results"][i]["original_language"]
    langList.append(language)

for i in range(len(pg4["results"])):
    language = pg4["results"][i]["original_language"]
    langList.append(language)
    

for i in range(len(pg5["results"])):
    language = pg5["results"][i]["original_language"]
    langList.append(language)

print(langList)
en = langList.count('en')
fr = langList.count('fr')
te = langList.count('te')
isCount = langList.count('is')
it = langList.count('it')
es = langList.count('es')
pl = langList.count('pl')
hi = langList.count('hi')
ja =langList.count('ja')
ko = langList.count('ko')
pt = langList.count('pt')
uk = langList.count('uk')
zh = langList.count('zh')

# %%
df = pd.DataFrame (
    {
    "Language": ["English", "French", "Telugu", "Icelandic", "Italian", "Spanish", "Polish", "Hindi", "Japanese", "Korean", "Portuguese", "Ukranian", "Mandarin"],
    "Count": [en, fr, te, isCount, it, es, pl, hi, ja, ko, pt, uk, zh]
    }
)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12, 5))
plt.title("Movie Languages in 2023")
ax = sns.barplot(x = df['Language'], y = df["Count"])

ax.bar_label(ax.containers[0])

# %%
df2 = pd.DataFrame(
    {
    "Languages": langList
    }
)

# %%
sns.countplot(x = df2["Languages"])
plt.title("Movie Languages in 2023")
plt.ylabel("Frequency")
